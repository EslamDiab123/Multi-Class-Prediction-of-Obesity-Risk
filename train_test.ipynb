# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder , StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\Almodather\Downloads\playground-series-s4e2\train.csv')

# %% [markdown]
# # 1-Explore Data

# %%
df.head()
# Out:
#    id  Gender        Age    Height      Weight family_history_with_overweight  \
# 0   0    Male  24.443011  1.699998   81.669950                            yes
# 1   1  Female  18.000000  1.560000   57.000000                            yes
# 2   2  Female  18.000000  1.711460   50.165754                            yes
# 3   3  Female  20.952737  1.710730  131.274851                            yes
# 4   4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad
# ...

# %%
df.shape
# Out:
# (20758, 18)

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Height', 'Weight',
#        'family_history_with_overweight', 'FAVC', 'FCVC', 'NCP', 'CAEC',
#        'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20758 entries, 0 to 20757
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20758 non-null  int64
#  1   Gender                          20758 non-null  object
#  2   Age                             20758 non-null  float64
#  3   Height                          20758 non-null  float64
#  4   Weight                          20758 non-null  float64
#  5   family_history_with_overweight  20758 non-null  object
#  6   FAVC                            20758 non-null  object
#  7   FCVC                            20758 non-null  float64
#  8   NCP                             20758 non-null  float64
#  9   CAEC                            20758 non-null  object
#  10  SMOKE                           20758 non-null  object
#  11  CH2O                            20758 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# id                                0
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#           count          mean          std    min          25%           50%  \
# id      20758.0  10378.500000  5992.462780   0.00  5189.250000  10378.500000
# Age     20758.0     23.841804     5.688072  14.00    20.000000     22.815416
# Height  20758.0      1.700245     0.087312   1.45     1.631856      1.700000
# Weight  20758.0     87.887768    26.379443  39.00    66.000000     84.064875
# FCVC    20758.0      2.445908     0.533218   1.00     2.000000      2.393837
# NCP     20758.0      2.761332     0.705375   1.00     3.000000      3.000000
# CH2O    20758.0      2.029418     0.608467   1.00     1.792022      2.000000
# FAF     20758.0      0.981747     0.838302   0.00     0.008013      1.000000
# TUE     20758.0      0.616756     0.602113   0.00     0.000000      0.573887
#
#                  75%           max
# id      15567.750000  20757.000000
# Age        26.000000     61.000000
# Height      1.762887      1.975663
# Weight    111.600553    165.057269
# ...

# %% [markdown]
# # Transform Data

# %%
la=LabelEncoder()

# %%
obj=df.select_dtypes(include='object')
non_obj=df.select_dtypes(exclude='object')

# %%
obj
# Out:
#        Gender family_history_with_overweight FAVC        CAEC SMOKE SCC  \
# 0        Male                            yes  yes   Sometimes    no  no
# 1      Female                            yes  yes  Frequently    no  no
# 2      Female                            yes  yes   Sometimes    no  no
# 3      Female                            yes  yes   Sometimes    no  no
# 4        Male                            yes  yes   Sometimes    no  no
# ...       ...                            ...  ...         ...   ...  ..
# 20753    Male                            yes  yes   Sometimes    no  no
# 20754    Male                             no  yes  Frequently    no  no
# 20755    Male                            yes  yes   Sometimes    no  no
# 20756    Male                            yes  yes   Sometimes    no  no
# 20757    Male                            yes  yes   Sometimes    no  no
#
#             CALC                 MTRANS           NObeyesdad
# ...

# %%
for i in range (0,obj.shape[1]):
   obj.iloc[:,i]= la.fit_transform(obj.iloc[:,i])

# %%
obj
# Out:
#       Gender family_history_with_overweight FAVC CAEC SMOKE SCC CALC MTRANS  \
# 0          1                              1    1    2     0   0    1      3
# 1          0                              1    1    1     0   0    2      0
# 2          0                              1    1    2     0   0    2      3
# 3          0                              1    1    2     0   0    1      3
# 4          1                              1    1    2     0   0    1      3
# ...      ...                            ...  ...  ...   ...  ..  ...    ...
# 20753      1                              1    1    2     0   0    1      3
# 20754      1                              0    1    1     0   0    1      3
# 20755      1                              1    1    2     0   0    2      3
# 20756      1                              1    1    2     0   0    2      0
# 20757      1                              1    1    2     0   0    1      3
#
#       NObeyesdad
# 0              6
# 1              1
# ...

# %%
obj=obj.astype("int")

# %%
obj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20758 entries, 0 to 20757
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          20758 non-null  int32
#  1   family_history_with_overweight  20758 non-null  int32
#  2   FAVC                            20758 non-null  int32
#  3   CAEC                            20758 non-null  int32
#  4   SMOKE                           20758 non-null  int32
#  5   SCC                             20758 non-null  int32
#  6   CALC                            20758 non-null  int32
#  7   MTRANS                          20758 non-null  int32
#  8   NObeyesdad                      20758 non-null  int32
# dtypes: int32(9)
# memory usage: 729.9 KB

# %%
data=pd.concat([obj,non_obj],axis=1)

# %%
test=pd.read_csv(r'C:\Users\Almodather\Downloads\playground-series-s4e2\test.csv')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13840 entries, 0 to 13839
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              13840 non-null  int64
#  1   Gender                          13840 non-null  object
#  2   Age                             13840 non-null  float64
#  3   Height                          13840 non-null  float64
#  4   Weight                          13840 non-null  float64
#  5   family_history_with_overweight  13840 non-null  object
#  6   FAVC                            13840 non-null  object
#  7   FCVC                            13840 non-null  float64
#  8   NCP                             13840 non-null  float64
#  9   CAEC                            13840 non-null  object
#  10  SMOKE                           13840 non-null  object
#  11  CH2O                            13840 non-null  float64
# ...

# %%
obj_test=test.select_dtypes(include='object')
non_obj_test=test.select_dtypes(exclude='object')

# %%
for i in range(0,obj_test.shape[1]):
    obj_test.iloc[:,i]=la.fit_transform(obj_test.iloc[:,i])

# %%
obj_test=obj_test.astype('int')

# %%
data_test=pd.concat([obj_test,non_obj_test],axis=1)

# %%
sc=StandardScaler()

# %%
scal1=data_test[['Age']]
scal2=data_test[['Weight']]
data_test['Age']=sc.fit_transform(scal1)
data_test['Weight']=sc.fit_transform(scal2)

# %%
data_test.head()
# Out:
#    Gender  family_history_with_overweight  FAVC  CAEC  SMOKE  SCC  CALC  \
# 0       1                               1     1     2      0    0     2
# 1       0                               1     1     2      0    0     2
# 2       0                               1     1     2      0    0     2
# 3       1                               1     1     2      0    0     2
# 4       0                               1     1     2      0    0     2
#
#    MTRANS     id       Age    Height    Weight      FCVC       NCP      CH2O  \
# 0       3  20758  0.508163  1.848294  1.273786  2.938616  3.000000  2.825629
# 1       3  20759 -0.509128  1.600000 -0.818988  2.000000  1.000000  3.000000
# 2       3  20760  0.353000  1.643355  0.927432  3.000000  3.000000  2.621877
# 3       3  20761 -0.512705  1.553127  0.623672  2.000000  2.977909  2.786417
# 4       3  20762  0.353000  1.627396  0.668336  3.000000  3.000000  2.653531
#
#         FAF       TUE
# 0  0.855400  0.000000
# 1  1.000000  0.000000
# ...

# %%
scal3=data[['Age']]
scal4=data[['Weight']]
data['Age']=sc.fit_transform(scal3)
data['Weight']=sc.fit_transform(scal4)

# %% [markdown]
# # Creat Model

# %%
data.head()
# Out:
#    Gender  family_history_with_overweight  FAVC  CAEC  SMOKE  SCC  CALC  \
# 0       1                               1     1     2      0    0     1
# 1       0                               1     1     1      0    0     2
# 2       0                               1     1     2      0    0     2
# 3       0                               1     1     2      0    0     1
# 4       1                               1     1     2      0    0     1
#
#    MTRANS  NObeyesdad  id       Age    Height    Weight      FCVC       NCP  \
# 0       3           6   0  0.105699  1.699998 -0.235713  2.000000  2.983297
# 1       0           1   1 -1.027052  1.560000 -1.170931  2.000000  3.000000
# 2       3           0   2 -1.027052  1.711460 -1.430012  1.880534  1.411685
# 3       3           4   3 -0.507929  1.710730  1.644770  3.000000  3.000000
# 4       3           6   4  1.371197  1.914186  0.224054  2.679664  1.971472
#
#        CH2O       FAF       TUE
# 0  2.763573  0.000000  0.976473
# ...

# %%
x= data.drop(["id","NObeyesdad"],axis=1)

# %%
y=data['NObeyesdad']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=21)

# %%
model1=LogisticRegression()

# %%
model1=LogisticRegression()
model2=RandomForestClassifier()
model3=GaussianNB()
model4=SVC()
model5=XGBClassifier(learning_rate= 0.1, max_depth=3, n_estimators= 300)
model6=GradientBoostingClassifier()

# %%
def pred(model):
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    print(classification_report(pre,y_test))

# %%
pred(model1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82       560
#            1       0.72      0.71      0.71       642
#            2       0.78      0.81      0.79       574
#            3       0.96      0.92      0.94       634
#            4       1.00      0.99      1.00       823
#            5       0.58      0.67      0.62       418
#            6       0.63      0.62      0.63       501
#
#     accuracy                           0.81      4152
#    macro avg       0.79      0.79      0.79      4152
# weighted avg       0.81      0.81      0.81      4152

# %%
pred(model2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       528
#            1       0.90      0.86      0.88       664
#            2       0.88      0.90      0.89       585
#            3       0.97      0.97      0.97       608
#            4       1.00      1.00      1.00       820
#            5       0.75      0.84      0.79       431
#            6       0.84      0.79      0.81       516
#
#     accuracy                           0.90      4152
#    macro avg       0.89      0.90      0.89      4152
# weighted avg       0.91      0.90      0.91      4152

# %%
pred(model4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89       570
#            1       0.78      0.81      0.79       610
#            2       0.82      0.85      0.83       580
#            3       0.97      0.95      0.96       618
#            4       1.00      1.00      1.00       820
#            5       0.63      0.72      0.67       422
#            6       0.74      0.68      0.71       532
#
#     accuracy                           0.85      4152
#    macro avg       0.84      0.84      0.84      4152
# weighted avg       0.86      0.85      0.85      4152

# %%
pred(model3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.69      0.77       668
#            1       0.47      0.64      0.54       459
#            2       0.60      0.40      0.48       893
#            3       0.93      0.69      0.79       826
#            4       1.00      0.96      0.98       853
#            5       0.27      0.61      0.38       217
#            6       0.26      0.53      0.35       236
#
#     accuracy                           0.66      4152
#    macro avg       0.63      0.65      0.61      4152
# weighted avg       0.74      0.66      0.69      4152

# %%
pred(model5)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       530
#            1       0.89      0.88      0.88       643
#            2       0.87      0.91      0.89       575
#            3       0.98      0.96      0.97       619
#            4       1.00      1.00      1.00       821
#            5       0.78      0.85      0.81       444
#            6       0.86      0.81      0.83       520
#
#     accuracy                           0.91      4152
#    macro avg       0.90      0.90      0.90      4152
# weighted avg       0.91      0.91      0.91      4152

# %%
pred(model6)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       526
#            1       0.90      0.87      0.88       650
#            2       0.88      0.91      0.89       577
#            3       0.97      0.96      0.97       612
#            4       1.00      1.00      1.00       819
#            5       0.78      0.84      0.81       449
#            6       0.84      0.80      0.82       519
#
#     accuracy                           0.91      4152
#    macro avg       0.90      0.90      0.90      4152
# weighted avg       0.91      0.91      0.91      4152

# %%
prim_grid={'n_estimators':[100,200,300],'learning_rate':[0.1,0.01,0.001],"max_depth":[3,5,7]}
scorer= "accuracy"
mg5=GridSearchCV(model5,prim_grid,scoring=scorer,n_jobs=-1)

# %%
mg5.fit(x_train,y_train)
print(mg5.best_params_,mg5.best_score_)
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 300} 0.904913943179167

# %%
testx=data_test.drop('id',axis=1)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13840 entries, 0 to 13839
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              13840 non-null  int64
#  1   Gender                          13840 non-null  object
#  2   Age                             13840 non-null  float64
#  3   Height                          13840 non-null  float64
#  4   Weight                          13840 non-null  float64
#  5   family_history_with_overweight  13840 non-null  object
#  6   FAVC                            13840 non-null  object
#  7   FCVC                            13840 non-null  float64
#  8   NCP                             13840 non-null  float64
#  9   CAEC                            13840 non-null  object
#  10  SMOKE                           13840 non-null  object
#  11  CH2O                            13840 non-null  float64
# ...

# %%
prex=model5.predict(testx)

# %%
sub=pd.DataFrame({"id":data_test["id"],"NObeyesdad":prex})

# %%
sub["NObeyesdad"]=la.inverse_transform(prex)

# %%
print(np.unique(prex))
# Out:
# [0 1 2 3 4 5 6]

# %%
print(la.classes_)
# Out:
# ['Automobile' 'Bike' 'Motorbike' 'Public_Transportation' 'Walking']

# %%
# All possible labels including the missing ones
all_labels = ['Automobile', 'Bike', 'Motorbike', 'Public_Transportation', 'Walking', 'Scooter', 'Skateboard']

# Fit the LabelEncoder with all possible labels
la = LabelEncoder()
la.fit(all_labels)

# Check the classes in the encoder
print(la.classes_)

# Now, inverse transform should work
sub["NObeyesdad"] = la.inverse_transform(prex)
print(sub["NObeyesdad"])
# Out:
# ['Automobile' 'Bike' 'Motorbike' 'Public_Transportation' 'Scooter'
#  'Skateboard' 'Walking']
# 0        Public_Transportation
# 1                   Skateboard
# 2                      Scooter
# 3                    Motorbike
# 4                      Scooter
#                  ...
# 13835                  Walking
# 13836                     Bike
# 13837               Automobile
# 13838                     Bike
# 13839    Public_Transportation
# Name: NObeyesdad, Length: 13840, dtype: object

# %%
sub
# Out:
#           id             NObeyesdad
# 0      20758  Public_Transportation
# 1      20759             Skateboard
# 2      20760                Scooter
# 3      20761              Motorbike
# 4      20762                Scooter
# ...      ...                    ...
# 13835  34593                Walking
# 13836  34594                   Bike
# 13837  34595             Automobile
# 13838  34596                   Bike
# 13839  34597  Public_Transportation
#
# [13840 rows x 2 columns]
